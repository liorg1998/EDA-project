# %% [markdown]
# ## DA Final project:
# ## Group 19
# ## Income Of Adults
# #### Name of students:
# ###### Naama omeysi
# ###### Lior granik
#
# לסדר את התמונה
#
# ![salary-difference-wage-gap-rich-poor-people-different-incomes-professional-income-comparison-unequal-pay-vector-231555552.jpg](attachment:b83e171b-16dc-4970-ae2a-62fd5c6c5b80.jpg)

# %% [markdown]
# Information of the data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
url="https://raw.githubusercontent.com/liorg1998/EDA-project/main/adult_data.csv"
df_income= pd.read_csv(url)
df_income
#df_income.head()
# Out:
#        age          workclass   fnlwgt    education   education-num  \
# 0       39          State-gov    77516    Bachelors              13
# 1       50   Self-emp-not-inc    83311    Bachelors              13
# 2       38            Private   215646      HS-grad               9
# 3       53            Private   234721         11th               7
# 4       28            Private   338409    Bachelors              13
# ...    ...                ...      ...          ...             ...
# 32556   27            Private   257302   Assoc-acdm              12
# 32557   40            Private   154374      HS-grad               9
# 32558   58            Private   151910      HS-grad               9
# 32559   22            Private   201490      HS-grad               9
# 32560   52       Self-emp-inc   287927      HS-grad               9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df_income.columns
# Out:
# Index(['age', ' workclass', ' fnlwgt', ' education', ' education-num',
#        ' marital-status', ' occupation', ' relationship', ' race', ' sex',
#        ' capital-gain', ' capital-loss', ' hours-per-week', ' native-country',
#        ' salary'],
#       dtype='object')

# %%
#features=[' sex',' salary']
#df_income[features].corr(method='pearson')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Out:
# <AxesSubplot:xlabel=' sex', ylabel=' salary'>

# %%
df_income.shape
# Out:
# (32561, 15)

# %%
sns.scatterplot(data=df_income,x='age',y=' hours-per-week')
# Out:
# <AxesSubplot:xlabel='age', ylabel=' hours-per-week'>

# %%
df_income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              32561 non-null  int64
#  1    workclass       32561 non-null  object
#  2    fnlwgt          32561 non-null  int64
#  3    education       32561 non-null  object
#  4    education-num   32561 non-null  int64
#  5    marital-status  32561 non-null  object
#  6    occupation      32561 non-null  object
#  7    relationship    32561 non-null  object
#  8    race            32561 non-null  object
#  9    sex             32561 non-null  object
#  10   capital-gain    32561 non-null  int64
#  11   capital-loss    32561 non-null  int64
#  12   hours-per-week  32561 non-null  int64
#  13   native-country  32561 non-null  object
#  14   salary          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
# Out:
# array([' Male', ' Female'], dtype=object)

# %%
#features=[' workclass',' education',' marital-status',' occupation',' relationship',' race',' sex',' native-country',' salary']
#numbers=['age',' fnlwgt',' education-num',' hours-per-week']

#df_income = pd.get_dummies(features)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25772\27919232.py in <module>
#       1 plt.figure(figsize=(8,6))
# ----> 2 sns.heatmap(correlation_matrix,annot=True,cmap='coolwarm',fmt=".2f", linewidths=.5)
#       3 plt.title('Correlation Heatmap')
#       4 plt.show()
#
# NameError: name 'correlation_matrix' is not defined
